# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
io_data = pd.read_csv("C:/Users/RAAGH/Downloads/dataframe_.csv")

# %%
io_data
# Out:
#            input      output
# 0    -122.740667 -130.572085
# 1    -121.531419 -129.938929
# 2    -134.917019 -130.141832
# 3    -120.605951 -125.760932
# 4    -129.894781 -112.785214
# ...          ...         ...
# 1692   25.410184  -76.380902
# 1693   29.537304  -82.796934
# 1694   31.633331  -87.000000
# 1695   29.091458 -104.943052
# 1696   17.145296 -101.726894
#
# [1697 rows x 2 columns]

# %%
io_data.isnull().sum()
# Out:
# input     1
# output    1
# dtype: int64

# %%
io_data.shape
# Out:
# (1697, 2)

# %%
sns.relplot(x="input", y="output", data=io_data)

# %%
# regression analysis(machine learning techinique)
pyth_lm=smf.ols(formula='input~output', data=io_data).fit()
pyth_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  input   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     601.1
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):          7.31e-114
# Time:                        16:25:10   Log-Likelihood:                -9559.2
# No. Observations:                1696   AIC:                         1.912e+04
# Df Residuals:                    1694   BIC:                         1.913e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.1158      1.857     11.909      0.000      18.473      25.758
# ...

# %%
ax=plt.axes()
ax.set(facecolor="grey")
sns.set(rc={'figure.figsize':(15,10)},style='whitegrid')
ax.set_title('IO ANALYSIS',fontsize=15,fontweight="bold")
sns.barplot(y=output.index, x=input, orient='h',palette="icefire",saturation=1)
plt.xlabel('input')
plt.ylabel('output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12160/1097912474.py in <module>
#       3 sns.set(rc={'figure.figsize':(15,10)},style='whitegrid')
#       4 ax.set_title('IO ANALYSIS',fontsize=15,fontweight="bold")
# ----> 5 sns.barplot(y=output.index, x=input, orient='h',palette="icefire",saturation=1)
#       6 plt.xlabel('input')
#       7 plt.ylabel('output')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
# ...
